# %%
# Load necessary libraries
library(conflicted)
library(tidyverse)
# Out:
# Warning message:
# “package ‘dplyr’ was built under R version 4.3.2”
# Warning message:
# “package ‘stringr’ was built under R version 4.3.2”
# ── Attaching core tidyverse packages ──────────────────────── tidyverse 2.0.0 ──
# ✔ dplyr     1.1.4     ✔ readr     2.1.4
# ✔ forcats   1.0.0     ✔ stringr   1.5.1
# ✔ ggplot2   3.4.4     ✔ tibble    3.2.1
# ✔ lubridate 1.9.3     ✔ tidyr     1.3.0
# ✔ purrr     1.0.2

# %% [markdown]
# # Example of non-linear Relationship

# %%
# Load data
nonlinear_data <- read_csv("data/Sample_Datasets_Linear_Models/Fertilizer_cropyields.csv")

# Plot with ggplot2
ggplot(nonlinear_data, aes(x = FertilizerAmount, y = CropYield)) +
  geom_point() +
  geom_smooth(method = "lm", se = FALSE, color = "blue") +
  ggtitle("Non-Linear Relationship: Fertilizer Amount vs Crop Yield")
# Out:
# Rows: 100 Columns: 2
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# dbl (2): FertilizerAmount, CropYield
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %%
# Fit a linear model

model_nonlinear <- lm(CropYield ~ FertilizerAmount, data = nonlinear_data)

summary(model_nonlinear)


# Diagnostic plots
par(mfrow=c(2,2)) # Arrange plots in a 2x2 grid
plot(model_nonlinear)
# Out:
# Call:
# lm(formula = CropYield ~ FertilizerAmount, data = nonlinear_data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -42.839 -14.246   1.945  15.491  33.674
#
# Coefficients:
#                  Estimate Std. Error t value Pr(>|t|)
# (Intercept)      32.17828    3.74307   8.597 1.33e-13 ***
# FertilizerAmount  0.06289    0.06759   0.930    0.354
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 19.49 on 98 degrees of freedom
# Multiple R-squared:  0.008756,	Adjusted R-squared:  -0.001358
# F-statistic: 0.8657 on 1 and 98 DF,  p-value: 0.3544
# Plot with title “”

# %% [markdown]
# # Example of heteroscedasticity

# %%
# Load data
heteroscedasticity_data <- read_csv("data/Sample_Datasets_Linear_Models/Income_vs_Expense_Heteroscedasticity.csv")


# Plot with ggplot2
ggplot(heteroscedasticity_data, aes(y = Expenses , x=Income)) +
  geom_point() +
  geom_smooth(method = "lm", se = FALSE, color = "blue") +
  ggtitle("heteroscedasticity example: Expenses vs Income")
# Out:
# Rows: 100 Columns: 2
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# dbl (2): Income, Expenses
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %%
# Fit a linear model

model_heteroscedasticity <- lm(Expenses ~ Income, data = heteroscedasticity_data)

summary(model_heteroscedasticity)

# Diagnostic plots
par(mfrow=c(2,2)) # Arrange plots in a 2x2 grid
plot(model_heteroscedasticity)
# Out:
# Call:
# lm(formula = Expenses ~ Income, data = heteroscedasticity_data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -13266.9  -2779.3   -357.2   2962.6  12113.9
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -1.727e+03  1.491e+03  -1.158     0.25
# Income       3.315e-01  2.986e-02  11.101   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 4394 on 98 degrees of freedom
# Multiple R-squared:  0.557,	Adjusted R-squared:  0.5525
# F-statistic: 123.2 on 1 and 98 DF,  p-value: < 2.2e-16
# Plot with title “”

# %% [markdown]
# # Example of Dataset with Extreme Cook's Distance

# %%
# Load data
cooks_data <- read_csv("data/Sample_Datasets_Linear_Models/Influential_Student_Performance.csv")


# Plot with ggplot2
ggplot(cooks_data, aes(y = Grades , x=HoursStudied)) +
  geom_point() +
  geom_smooth(method = "lm", se = FALSE, color = "blue") +
  ggtitle("Cooks example: Grades vs HoursStudied")
# Out:
# Rows: 100 Columns: 2
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# dbl (2): HoursStudied, Grades
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# `geom_smooth()` using formula = 'y ~ x'
# plot without title

# %%
# Fit a linear model

model_cooks <- lm(Grades ~ HoursStudied, data = cooks_data)

summary(model_cooks)

# diagnostic plots
par(mfrow=c(2,2)) # arrange plots in a 2x2 grid
plot(model_cooks)
# Out:
# Call:
# lm(formula = Grades ~ HoursStudied, data = cooks_data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -11.571  -3.295  -1.050   2.804  54.536
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)    9.8005     1.6734   5.857 6.31e-08 ***
# HoursStudied   2.1617     0.2904   7.445 3.80e-11 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 8.539 on 98 degrees of freedom
# Multiple R-squared:  0.3613,	Adjusted R-squared:  0.3547
# F-statistic: 55.43 on 1 and 98 DF,  p-value: 3.802e-11
# Plot with title “”

# %% [markdown]
# # Example of Dataset with Multicollinearity

# %%
# Load data
multicollinearity_data <- read_csv("data/Sample_Datasets_Linear_Models/Real_Estate_Multicollinearity.csv")

# Use the ggpairs function to create a matrix of scatterplots with ggplot2
GGally::ggpairs(multicollinearity_data,title="House Data - Pairs Plot")
# Out:
# Rows: 1000 Columns: 4
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# dbl (4): nbedrooms, nbathrooms, price, sqft
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Registered S3 method overwritten by 'GGally':
#   method from
#   +.gg   ggplot2
# plot without title

# %%
# Fit a linear model

model_multicollinearity <- lm(sqft ~ nbedrooms + nbathrooms+price, data = multicollinearity_data)

summary(model_multicollinearity)

# diagnostic plots
par(mfrow=c(2,2)) # arrange plots in a 2x2 grid
plot(model_multicollinearity)
# Out:
# Call:
# lm(formula = sqft ~ nbedrooms + nbathrooms + price, data = multicollinearity_data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -133.22  -29.56    0.63   28.85  137.51
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept) -6.151e+02  2.435e+01 -25.260   <2e-16 ***
# nbedrooms    1.737e+01  7.196e+00   2.414   0.0159 *
# nbathrooms   8.300e+00  3.989e+00   2.081   0.0377 *
# price        8.060e-03  1.193e-04  67.543   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 43.15 on 996 degrees of freedom
# Multiple R-squared:  0.9966,	Adjusted R-squared:  0.9966
# F-statistic: 9.691e+04 on 3 and 996 DF,  p-value: < 2.2e-16
# Plot with title “”

# %%
car::vif(model_multicollinearity) %>% print()
# Out:
#  nbedrooms nbathrooms      price
#  55.016552   5.572731  59.452175

# %%
Price and nbedrooms are have too much multicolinn
